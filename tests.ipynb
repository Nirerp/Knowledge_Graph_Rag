# %% [markdown]
# ## Imports

# %%
# Add project root to Python path ONLY FOR NOTEBOOK!!!
import sys
from pathlib import Path

project_root = (
    Path(__file__).resolve().parent if "__file__" in globals() else Path().resolve()
)
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from neo4j import GraphDatabase
from qdrant_client import QdrantClient, models
from dotenv import load_dotenv
from pydantic import BaseModel
from openai import OpenAI
from collections import defaultdict
from neo4j_graphrag.retrievers import QdrantNeo4jRetriever
import uuid
import os

from config.datasets import GraphComponents, Single

# %%
# Load environment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ## Setting Up Environment Variables

# %%
# Get credentials from environment variables (derived from docker-compose config)
qdrant_port = os.getenv("QDRANT_HTTP_PORT", "6333")
qdrant_host = os.getenv("QDRANT_URL", "http://localhost")
qdrant_url = f"{qdrant_host}:{qdrant_port}"


# Parse NEO4J_AUTH (format: username/password)
neo4j_auth = os.getenv("NEO4J_AUTH", "neo4j/password")
neo4j_username, neo4j_password = neo4j_auth.split("/", 1)
neo4j_bolt_port = os.getenv("NEO4J_BOLT_PORT")
neo4j_url = os.getenv("NEO4J_URL")
neo4j_uri = f"{neo4j_url}:{neo4j_bolt_port}"
# LLM:
llm_model = os.getenv("LLM_MODEL")
llm_api_key = os.getenv("LLM_API_KEY")

# Data and Other:
data_folder = os.getenv("RAW_DATA_FOLDER")

# %%
# Print out all envs:
print(qdrant_port)
print(qdrant_host)
print(qdrant_url)
print(neo4j_uri)
print(neo4j_username)
print(neo4j_password)
print(llm_model)
print(data_folder)
# Out:
# 6333
# http://localhost
# http://localhost:6333
# bolt://localhost:7687
# neo4j
# password
# perplexity/sonar-pro
# ./raw_data/

# %% [markdown]
# ---

# %% [markdown]
# ## Initialization of Neo4j and Qdrant Clients

# %%
neo4j_driver = GraphDatabase.driver(neo4j_uri, auth=(neo4j_username, neo4j_password))

qdrant_client = QdrantClient(
    url=qdrant_url,
)

# %% [markdown]
# ---
# ## TEST - Graph Creation

# %%
from ingestion.orchestration import Orchestrator

orchestrator = Orchestrator(llm_model, llm_api_key)
orchestrator._test_response("What is the capital of France?")
# Out:
# 'The capital of France is **Paris**[1][2][3][5][6].\n\nParis serves as the national seat of government, culture, and commerce, located in the north-central part of the country along the Seine River[1][6]. Its position as the capital dates back to medieval times, first established under King Clovis I in 508 CE, and has remained so with only brief interruptions during periods of war or political turmoil[3][4][5]. Today, Paris is not only the political capital but also the largest city in France, with a population of over 2 million residents within city limits and a metropolitan area exceeding 10 million[2][6]. It is renowned globally for its historical landmarks such as the Eiffel Tower, Notre-Dame Cathedral, and the Louvre Museum, affirming its status as a major world city[1][5].'

# %%
testing_graph = orchestrator.llm_parser(
    "Zachary has 3 children: Refael (male), his sister Noah, and the youngest boy Beerih."
)

# %%
testing_graph
# Out:
# GraphComponents(graph=[Single(node='Zachary', relationship='parent of', target_node='Refael'), Single(node='Zachary', relationship='parent of', target_node='Noah'), Single(node='Zachary', relationship='parent of', target_node='Beerih'), Single(node='Refael', relationship='sibling of', target_node='Noah'), Single(node='Refael', relationship='sibling of', target_node='Beerih'), Single(node='Noah', relationship='sibling of', target_node='Refael'), Single(node='Noah', relationship='sibling of', target_node='Beerih'), Single(node='Beerih', relationship='sibling of', target_node='Refael'), Single(node='Beerih', relationship='sibling of', target_node='Noah'), Single(node='Noah', relationship='is sister of', target_node='Refael'), Single(node='Refael', relationship='is brother of', target_node='Noah'), Single(node='Beerih', relationship='is youngest brother of', target_node='Refael'), Single(node='Beerih', relationship='is youngest brother of', target_node='Noah')])

# %%
testing_graph.graph
# Out:
# [Single(node='Zachary', relationship='parent of', target_node='Refael'),
#  Single(node='Zachary', relationship='parent of', target_node='Noah'),
#  Single(node='Zachary', relationship='parent of', target_node='Beerih'),
#  Single(node='Refael', relationship='sibling of', target_node='Noah'),
#  Single(node='Refael', relationship='sibling of', target_node='Beerih'),
#  Single(node='Noah', relationship='sibling of', target_node='Refael'),
#  Single(node='Noah', relationship='sibling of', target_node='Beerih'),
#  Single(node='Beerih', relationship='sibling of', target_node='Refael'),
#  Single(node='Beerih', relationship='sibling of', target_node='Noah'),
#  Single(node='Noah', relationship='is sister of', target_node='Refael'),
#  Single(node='Refael', relationship='is brother of', target_node='Noah'),
#  Single(node='Beerih', relationship='is youngest brother of', target_node='Refael'),
#  Single(node='Beerih', relationship='is youngest brother of', target_node='Noah')]

# %%
for entry in testing_graph.graph:
    node = entry.node
    target_node = entry.target_node  # Get target node if available
    relationship = entry.relationship  # Get relationship if available
    print(f"NODE: {node}, TARGET NODE: {target_node}, RELATIONSHIP: {relationship}")
# Out:
# NODE: Zachary, TARGET NODE: Refael, RELATIONSHIP: parent of
# NODE: Zachary, TARGET NODE: Noah, RELATIONSHIP: parent of
# NODE: Zachary, TARGET NODE: Beerih, RELATIONSHIP: parent of
# NODE: Refael, TARGET NODE: Noah, RELATIONSHIP: sibling of
# NODE: Refael, TARGET NODE: Beerih, RELATIONSHIP: sibling of
# NODE: Noah, TARGET NODE: Refael, RELATIONSHIP: sibling of
# NODE: Noah, TARGET NODE: Beerih, RELATIONSHIP: sibling of
# NODE: Beerih, TARGET NODE: Refael, RELATIONSHIP: sibling of
# NODE: Beerih, TARGET NODE: Noah, RELATIONSHIP: sibling of
# NODE: Noah, TARGET NODE: Refael, RELATIONSHIP: is sister of
# NODE: Refael, TARGET NODE: Noah, RELATIONSHIP: is brother of
# NODE: Beerih, TARGET NODE: Refael, RELATIONSHIP: is youngest brother of
# NODE: Beerih, TARGET NODE: Noah, RELATIONSHIP: is youngest brother of

# %% [markdown]
# ---

# %% [markdown]
# ## TEST - graph extraction

# %%
from ingestion.file_reader import FileReader
from ingestion.chunker_embedder import ChunkerEmbedder

# %%
file_reader = FileReader(folder_path=data_folder)
files = file_reader.read_files()
# print(f"files: {files}")
chunk_embedder = ChunkerEmbedder(
    all_files=files,
    chunk_size=os.getenv("CHUNK_SIZE"),
    chunk_overlap=os.getenv("CHUNK_OVERLAP"),
)

# %%
for chunk in chunk_embedder.chunk_text():
    print(f"file name: {chunk['file']}")
    print(f"chunks: {chunk['chunks']}")
    print(f"amount of chunks: {len(chunk['chunks'])}")
# Out:
# file name: raw_text.txt
# chunks: ["The glob module in Python is used to find file paths that match a specified pattern using Unix shell-style wildcards.\n The primary function, glob.glob(), returns a list of path names matching a given pattern.\n For example, glob.glob('*.txt') will return all files in the current directory ending with .txt.", "To search recursively through subdirectories, the recursive parameter must be set to True, and the pattern ** is used to match any files and zero or more directories and subdirectories.\n For instance, glob.glob('**/*.py', recursive=True) will find all Python files in the current directory and all its subdirectories.\n The ** pattern can match across multiple directory levels, unlike *, which only matches files at the same directory level.", 'An alternative to glob.glob() is glob.iglob(), which returns an iterator instead of a list, making it more memory-efficient for large searches.\n This is particularly useful when dealing with a large number of files or directories.', "Special characters in the pattern, such as *, ?, and [], can be escaped using glob.escape() to match them literally.\n For example, glob.escape('?') returns '[?]', which matches the literal question mark character.\n The glob.translate() function can convert a path pattern into a regular expression for more complex matching.", 'When using glob, files starting with a dot (e.g., .hidden) are not matched by default unless the pattern explicitly includes a leading dot or the include_hidden parameter is set to True in Python 3.11 and later.\n The root_dir and dir_fd parameters allow specifying a root directory or directory descriptor for the search, respectively.']
# amount of chunks: 5
# file name: short_story.txt
# chunks: ['In the town of Mipple-Moo, where roofs were square and doors were blue, lived a tiny girl named Tindle Tock who dreamed of catching the moon in a sock. Every night, she’d climb the Lolly Tree, the tallest tree for miles to see, waving her net and shouting, “Hey Moon! Come play before it’s half past noon!”', 'But the moon, as moons often do, just blinked and softly said, “A-choo! Dear Tindle Tock, I can’t come near—earth’s too wobbly, dark, and clear!” Still, Tindle didn’t quit or sigh. She schemed and planned beneath the sky, sketching blueprints made of thread and glue, a moon-catcher shaped like a shoe.', 'Her friends arrived—Finkle Fox with socks of green and stripes of clocks, Wobble the Croc who juggled stones, and Pib the Pig with silver bones. “You’ll never catch that moon, my dear,” said Croc, while twirling ear to ear. “It’s slippery, high, and far too bright! It only comes out late at night!”', 'But Tindle grinned, her eyes alight. “Then late at night we’ll take our flight!” She built a rocket out of spoons, old kites, and music from baboons. It sputtered, burped, and with a boom, it whooshed right past the town’s perfume. Through clouds of gum and stars of jam, straight to the moon—yes sir, she swam!', 'The moon looked shy and asked, “What’s this?”\nTindle smiled and blew a kiss. “I don’t want to trap or steal your gleam… I only came to share a dream.” The moon then beamed, its glow so wide, it shimmered warm from side to side.\n\nWhen Tindle landed back in town, she wore moonlight as her crown. The folks of Mipple-Moo all cheered, “You did the thing we all once feared!”', 'And from that day, each Mipple child was told that dreams, no matter wild, should never stop for doubt or gloom—because someone once danced with the moon.']
# amount of chunks: 6

# %%
from ingestion.orchestration import Orchestrator

# %%
orchestrator = Orchestrator(llm_model, llm_api_key)

# %%
# text_chunks = chunk_embedder.chunk_text()

# %%
# nodes, relationships = orchestrator.extract_graph_components(text_chunks)

# %%
# print("TEXT CHUNKS NODES AND RELATIONSHIPS")
# print(f"nodes: {nodes}")
# print("=" * 100)
# print(f"relationships: {relationships}")

# %%
pdf_chunks = chunk_embedder.chunk_pdf()
nodes, relationships = orchestrator.extract_graph_components(pdf_chunks)
# Out:
# 2025-11-24 13:50:03,259 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-11-24 13:50:03,270 - INFO - Going to convert document batch...
# 2025-11-24 13:50:03,271 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 44ae89a68fc272bc7889292e9b5a1bad
# 2025-11-24 13:50:03,279 - INFO - Loading plugin 'docling_defaults'
# 2025-11-24 13:50:03,282 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-11-24 13:50:03,289 - INFO - Loading plugin 'docling_defaults'
# 2025-11-24 13:50:03,293 - INFO - Registered ocr engines: ['auto', 'easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-11-24 13:50:03,954 - INFO - Accelerator device: 'cpu'
# [INFO] 2025-11-24 13:50:03,971 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2025-11-24 13:50:03,978 [RapidOCR] download_file.py:60: File exists and is valid: /home/nir/projects/graph_rag/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.onnx
# [INFO] 2025-11-24 13:50:03,979 [RapidOCR] main.py:53: Using /home/nir/projects/graph_rag/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.onnx
# [INFO] 2025-11-24 13:50:04,060 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2025-11-24 13:50:04,062 [RapidOCR] download_file.py:60: File exists and is valid: /home/nir/projects/graph_rag/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2025-11-24 13:50:04,063 [RapidOCR] main.py:53: Using /home/nir/projects/graph_rag/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2025-11-24 13:50:04,113 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2025-11-24 13:50:04,122 [RapidOCR] download_file.py:60: File exists and is valid: /home/nir/projects/graph_rag/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.onnx
# [INFO] 2025-11-24 13:50:04,123 [RapidOCR] main.py:53: Using /home/nir/projects/graph_rag/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.onnx
# 2025-11-24 13:50:04,235 - INFO - Auto OCR model selected rapidocr with onnxruntime.
# 2025-11-24 13:50:04,239 - INFO - Accelerator device: 'cpu'
# 2025-11-24 13:50:04,960 - INFO - Accelerator device: 'cpu'
# 2025-11-24 13:50:05,291 - INFO - Processing document Nir_Potasman_CV.pdf
# 2025-11-24 13:50:07,198 - INFO - Finished converting document Nir_Potasman_CV.pdf in 3.94 sec.
# 13:50:07 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:50:07,248 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:50:15 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:50:15,937 - INFO - Wrapper: Completed Call, calling success_handler
# 13:50:15 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:50:15,946 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:50:20 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:50:20,136 - INFO - Wrapper: Completed Call, calling success_handler
# 13:50:20 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:50:20,142 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:50:26 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:50:26,175 - INFO - Wrapper: Completed Call, calling success_handler
# 13:50:26 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:50:26,180 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:50:29 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:50:29,798 - INFO - Wrapper: Completed Call, calling success_handler
# 13:50:29 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:50:29,803 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:50:44 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:50:44,651 - INFO - Wrapper: Completed Call, calling success_handler
# 13:50:44 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:50:44,657 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:50:54 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:50:54,961 - INFO - Wrapper: Completed Call, calling success_handler
# 13:50:54 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:50:54,970 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:50:58 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:50:58,946 - INFO - Wrapper: Completed Call, calling success_handler
# 13:50:58 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:50:58,951 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:51:02 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:51:02,120 - INFO - Wrapper: Completed Call, calling success_handler
# 13:51:02 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:51:02,124 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:51:09 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:51:09,801 - INFO - Wrapper: Completed Call, calling success_handler
# 13:51:09 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:51:09,806 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:51:13 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:51:13,376 - INFO - Wrapper: Completed Call, calling success_handler
# 13:51:13 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:51:13,384 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:51:23 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:51:23,009 - INFO - Wrapper: Completed Call, calling success_handler
# 13:51:23 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:51:23,013 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:51:33 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:51:33,059 - INFO - Wrapper: Completed Call, calling success_handler
# 13:51:33 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:51:33,067 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:51:42 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:51:42,053 - INFO - Wrapper: Completed Call, calling success_handler
# 13:51:42 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:51:42,061 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:51:48 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:51:48,281 - INFO - Wrapper: Completed Call, calling success_handler
# 13:51:48 - LiteLLM:INFO: utils.py:3427 -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 2025-11-24 13:51:48,290 - INFO -
# LiteLLM completion() model= sonar-pro; provider = perplexity
# 13:51:53 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:51:53,112 - INFO - Wrapper: Completed Call, calling success_handler

# %%
print("PDF CHUNKS NODES AND RELATIONSHIPS")
print(f"nodes: {nodes}")
print("=" * 100)
print(f"relationships: {relationships}")
# Out:
# PDF CHUNKS NODES AND RELATIONSHIPS
# nodes: {'Data Scientist': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'advanced analytics': '29cc6153-92af-4d9d-9b91-62952526d9ff', 'biology': '08e1c245-55ba-47a6-a169-e4535276cba6', 'medicine': '816b75d9-bc9d-48e6-bbdd-e3753ff1286c', 'machine learning': '4eb204f6-2331-4bc4-8fa9-80833c3dbe6b', 'statistical modeling': '97fbfa09-cba5-4426-9bd7-9bf7f1b20a59', 'data-informed decision-making': '104536fa-f5b0-46a0-9c44-8d575934ac22', 'extracting actionable insights': '23e2d238-f526-48f1-b1f8-32b831532b22', 'complex datasets': 'd4650e61-74d6-4f2d-8ec6-6f241fcf2f84', 'technical stakeholders': '8ba7adad-179d-44f3-9bf0-22947adfe496', 'non-technical stakeholders': 'a06d7b9d-46cf-4971-b7ca-92ca9f7900db', 'Linux': '50199455-1705-4f4f-ad28-720d5430d105', 'C': 'ab3c84d6-25ec-4419-a522-bc02463e9329', 'AWS': '9987cc9a-2679-485a-be6b-f50e087d2ba9', 'Docker': '72e41cf4-0a4d-425d-b6b8-2a5c8ae564b1', 'Python': '35dc956d-5eed-4a1f-afa9-cc6b67de0503', 'NoSQL': '4ee5ed47-8043-455e-ae7d-79203e6efb71', 'SQL': '0924c4b6-2743-406f-b830-4ccef5be2df6', 'solving challenging problems': '93a6737c-225e-4aff-b7c9-ff382feee9ab', 'innovative solutions': '7d26f4a0-f1b6-4023-8c11-50cd83e35034', 'business growth': '8fc05242-aebf-47cd-94f8-373fd60caa94', 'operational efficiency': 'fb4b9d96-58c3-4ab0-80ff-ffad9451f3fc', 'Machine Learning': 'fd70c7a3-4cdb-4bd1-9846-36b16a809f6b', 'AI': '872e7813-378c-49e8-be8a-0e7803c97a6b', 'Statistical Analysis': 'e3078895-b0fb-4b83-8b8f-2dfe5d82b277', 'Data Visualization': '6ff38470-8fde-4bcb-9c66-107f7787a634', 'LLMs': '5f267a92-1f9b-402d-a620-9caad94d79f8', 'Nodes': '728c3c62-8056-4413-a79a-0591ed5e3e8c', 'Relationships': '4c8414b4-6cef-4a10-9682-c40fba285276', 'Knowledge Graph': 'e7d0630b-e133-4a8b-bac4-918806357b32', 'Entities': 'd50b1c91-20ea-47c0-b9c0-769b742e8313', 'Person': '64a6f14e-4f77-48dc-9d8f-32231fc90754', 'Bachelor of Science in Biology & Life-Science': '0efca2f3-93e0-4441-bd7d-2ae6768eabdf', 'Tel-Aviv University': 'ef88b0b0-19ca-4c3b-a019-83cc454afb51', '2015-2018': '3c7308b0-f018-46a4-993e-956c638b743d', 'Bachelor of Medical Sciences': '888f30eb-eb4b-4a84-8a5d-d8dc1c2085db', '2020-2022': '052a4d9d-620d-409f-88b0-b43a9ab5518c', 'Doctor of Medicine': '366c5593-97d0-447c-9d84-30e8be9303a6', '2020': '751a2133-958f-4d7a-83eb-4854ba57fc9e', 'Pause': '22cec3a0-d853-4615-b0ed-05a6e16fee28', 'Monday, November 24, 2025, 11:50:21 AM UTC': '69fd9c91-4c5a-4a8d-b0d5-82408d3064af', 'AI Engineer': 'a26c6dd2-96ca-457b-8997-cf9bd6db33e2', 'Finubit': 'f3054234-7659-4d66-866c-1fad361b9b93', '2025': 'd272583d-4d64-4731-a6e5-34cc2431d73e', 'Present': '517655db-d1db-446c-be85-7353a9f5820f', 'Multi-agent AI platform': 'b38b860b-34a5-4c5b-93dd-bf91087dfa9a', 'Temporal workflows': '5ac40531-6cf3-4faa-bfc8-f13434af9c10', 'Pydantic AI': 'b1f7634f-4452-4c24-a70b-9fd66fd1a9f1', 'LangChain': '29ebabe3-5ea2-41f9-9e86-88d625d866e4', 'LiteLLM': '829e65fe-96f4-4106-a1f9-93b0ca9600ef', 'AWS Bedrock': 'ff55ca54-03a7-4a35-8fb4-c7e3e612b495', 'scalable, robust LLM-powered automation': 'd3054a7d-f46d-445e-9101-24fd370dd369', 'Microservices system': '40d18f4b-3fde-4a36-8c7f-65cb6163aee1', 'Kubernetes (Kind)': '22e4dccb-a886-4a24-ab74-2d77ba9a7ef2', 'observability stack': '1a91a43b-c781-45a2-b6ff-3bd9b1810449', 'Observability stack': '80469b24-ef5a-47f8-a031-9914879cda4c', 'Grafana': '2a621c53-b2f2-4f5c-91c9-13715fe3f9dc', 'Loki': '0dc546e2-7c0f-4007-a4da-b56418bc57f1', 'Tempo': '21cdb92e-5cfd-4149-ad77-037f8a880de8', 'Model Context Protocol (MCP) servers': '51edb252-e23f-47ae-a941-c52aa0e8b1d0', 'YAML-driven agent configuration': 'e8dba05c-730b-4c66-8677-22ffb6c08c9a', 'custom MCP integrations': 'babeb6bd-bf61-443c-8f4b-550ec62e4034', 'dynamic, code-free deployment for non-technical users': 'df7fe0ca-611c-4b2c-9a87-bf86bc846642', 'Real-time, persistent conversation workflows': '1ef598cf-e499-4937-a011-faf1caebf266', 'FastAPI backend': '62e37a44-0757-4d3d-8d04-8be6267dc0f4', 'session durability': 'bd49c7b0-4484-4143-8dca-4f4224cb4f22', 'state management': 'ee6 ...
# ====================================================================================================
# relationships: [{'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '29cc6153-92af-4d9d-9b91-62952526d9ff', 'type': 'leverages', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '08e1c245-55ba-47a6-a169-e4535276cba6', 'type': 'has_background_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '816b75d9-bc9d-48e6-bbdd-e3753ff1286c', 'type': 'has_background_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '4eb204f6-2331-4bc4-8fa9-80833c3dbe6b', 'type': 'has_background_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '97fbfa09-cba5-4426-9bd7-9bf7f1b20a59', 'type': 'has_background_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '104536fa-f5b0-46a0-9c44-8d575934ac22', 'type': 'drives', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '23e2d238-f526-48f1-b1f8-32b831532b22', 'type': 'skilled_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': 'd4650e61-74d6-4f2d-8ec6-6f241fcf2f84', 'type': 'extracts_from', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '8ba7adad-179d-44f3-9bf0-22947adfe496', 'type': 'communicates_findings_to', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': 'a06d7b9d-46cf-4971-b7ca-92ca9f7900db', 'type': 'communicates_findings_to', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '50199455-1705-4f4f-ad28-720d5430d105', 'type': 'proficient_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': 'ab3c84d6-25ec-4419-a522-bc02463e9329', 'type': 'proficient_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '9987cc9a-2679-485a-be6b-f50e087d2ba9', 'type': 'proficient_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '72e41cf4-0a4d-425d-b6b8-2a5c8ae564b1', 'type': 'proficient_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '35dc956d-5eed-4a1f-afa9-cc6b67de0503', 'type': 'proficient_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '4ee5ed47-8043-455e-ae7d-79203e6efb71', 'type': 'proficient_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '0924c4b6-2743-406f-b830-4ccef5be2df6', 'type': 'proficient_in', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '93a6737c-225e-4aff-b7c9-ff382feee9ab', 'type': 'passionate_about', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'c192436d-38c5-45a7-968c-d4b2c0cb2514', 'target': '7d26f4a0-f1b6-4023-8c11-50cd83e35034', 'type': 'delivers', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': '7d26f4a0-f1b6-4023-8c11-50cd83e35034', 'target': '8fc05242-aebf-47cd-94f8-373fd60caa94', 'type': 'drive', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': '7d26f4a0-f1b6-4023-8c11-50cd83e35034', 'target': 'fb4b9d96-58c3-4ab0-80ff-ffad9451f3fc', 'type': 'drive', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'fd70c7a3-4cdb-4bd1-9846-36b16a809f6b', 'target': '872e7813-378c-49e8-be8a-0e7803c97a6b', 'type': 'is a subfield of', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': '872e7813-378c-49e8-be8a-0e7803c97a6b', 'target': 'fd70c7a3-4cdb-4bd1-9846-36b16a809f6b', 'type': 'includes', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'fd70c7a3-4cdb-4bd1-9846-36b16a809f6b', 'target': 'e3078895-b0fb-4b83-8b8f-2dfe5d82b277', 'type': 'enables', 'source_file': 'Nir_Potasman_CV.pdf'}, {'source': 'e3078895-b0fb- ...

# %% [markdown]
# ---

# %% [markdown]
# # Embed the data

# %%
embedded_data = chunk_embedder.embed_chunks(pdf_chunks)
# Out:
# 13:51:59 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:51:59,494 - INFO - Wrapper: Completed Call, calling success_handler

# %% [markdown]
# ---

# %% [markdown]
# ## Ingest to Neo4J

# %%
from rag_handler.neo4j_orchestrator import Neo4jOrchestrator

neo4_orchestrator = Neo4jOrchestrator(
    neo4j_url=neo4j_uri, auth=(neo4j_username, neo4j_password)
)
neo4_orchestrator.ingest_to_neo4j(nodes, relationships)
# Out:
# 2025-11-24 13:52:01,329 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:leverages {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,368 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:has_background_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,377 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:has_background_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,386 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:has_background_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,395 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:has_background_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,436 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:drives {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,479 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:skilled_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,530 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:extracts_from {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,567 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:communicates_findings_to {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,578 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:communicates_findings_to {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,608 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:proficient_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,616 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:proficient_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,623 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:proficient_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,630 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:proficient_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,639 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:proficient_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,648 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:proficient_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,659 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:proficient_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,697 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:passionate_about {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,736 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:delivers {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,769 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:drive {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,783 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:drive {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,834 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:is_a_subfield_of {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,868 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:includes {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,904 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:enables {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,941 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:supports {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:01,976 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:enhances {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,020 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:advances {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,029 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:communicates_insights_from {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,081 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:are_part_of {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,132 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:extract {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,145 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:extract {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,204 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:build {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,248 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:represents {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,260 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:represents {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,288 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:earned_degree {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,329 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:conferred_by {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,373 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:duration {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,400 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:earned_degree {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,413 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:conferred_by {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,427 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:duration {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,465 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:enrolled_in {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,474 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:conferred_by {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,524 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:started {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,562 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:status {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,609 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:offers_degree {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,620 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:offers_degree {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,633 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:offers_degree {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,676 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:current_date {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,718 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:occupation {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,762 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:employer {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,811 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:employment_period_start {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,848 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:employment_period_end {original_type: $type, source_file: $source_file}]->(b)'
# 2025-11-24 13:52:02,885 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (b))} {position: line: 1, column: 1, offset: 0} for query: 'MATCH (a:Entity {id: $source_id}), (b:Entity {id: $target_id}) CREATE (a)-[:employs {original_type: $type, source_file: $source_file}]->(b)'
# ...
#  'non-technical stakeholders': 'a06d7b9d-46cf-4971-b7ca-92ca9f7900db',
#  'Linux': '50199455-1705-4f4f-ad28-720d5430d105',
#  'C': 'ab3c84d6-25ec-4419-a522-bc02463e9329',
#  'AWS': '9987cc9a-2679-485a-be6b-f50e087d2ba9',
#  'Docker': '72e41cf4-0a4d-425d-b6b8-2a5c8ae564b1',
#  'Python': '35dc956d-5eed-4a1f-afa9-cc6b67de0503',
#  'NoSQL': '4ee5ed47-8043-455e-ae7d-79203e6efb71',
#  'SQL': '0924c4b6-2743-406f-b830-4ccef5be2df6',
#  'solving challenging problems': '93a6737c-225e-4aff-b7c9-ff382feee9ab',
#  'innovative solutions': '7d26f4a0-f1b6-4023-8c11-50cd83e35034',
#  'business growth': '8fc05242-aebf-47cd-94f8-373fd60caa94',
#  'operational efficiency': 'fb4b9d96-58c3-4ab0-80ff-ffad9451f3fc',
#  'Machine Learning': 'fd70c7a3-4cdb-4bd1-9846-36b16a809f6b',
#  'AI': '872e7813-378c-49e8-be8a-0e7803c97a6b',
#  'Statistical Analysis': 'e3078895-b0fb-4b83-8b8f-2dfe5d82b277',
#  'Data Visualization': '6ff38470-8fde-4bcb-9c66-107f7787a634',
#  'LLMs': '5f267a92-1f9b-402d-a620-9caad94d79f8',
#  'Nodes': '728c3c62-8056-4413-a79a-0591ed5e3e8c',
#  'Relationships': '4c8414b4-6cef-4a10-9682-c40fba285276',
#  'Knowledge Graph': 'e7d0630b-e133-4a8b-bac4-918806357b32',
#  'Entities': 'd50b1c91-20ea-47c0-b9c0-769b742e8313',
#  'Person': '64a6f14e-4f77-48dc-9d8f-32231fc90754',
#  'Bachelor of Science in Biology & Life-Science': '0efca2f3-93e0-4441-bd7d-2ae6768eabdf',
#  'Tel-Aviv University': 'ef88b0b0-19ca-4c3b-a019-83cc454afb51',
#  '2015-2018': '3c7308b0-f018-46a4-993e-956c638b743d',
#  'Bachelor of Medical Sciences': '888f30eb-eb4b-4a84-8a5d-d8dc1c2085db',
#  '2020-2022': '052a4d9d-620d-409f-88b0-b43a9ab5518c',
#  'Doctor of Medicine': '366c5593-97d0-447c-9d84-30e8be9303a6',
#  '2020': '751a2133-958f-4d7a-83eb-4854ba57fc9e',
#  'Pause': '22cec3a0-d853-4615-b0ed-05a6e16fee28',
#  'Monday, November 24, 2025, 11:50:21 AM UTC': '69fd9c91-4c5a-4a8d-b0d5-82408d3064af',
#  'AI Engineer': 'a26c6dd2-96ca-457b-8997-cf9bd6db33e2',
#  'Finubit': 'f3054234-7659-4d66-866c-1fad361b9b93',
#  '2025': 'd272583d-4d64-4731-a6e5-34cc2431d73e',
#  'Present': '517655db-d1db-446c-be85-7353a9f5820f',
#  'Multi-agent AI platform': 'b38b860b-34a5-4c5b-93dd-bf91087dfa9a',
#  'Temporal workflows': '5ac40531-6cf3-4faa-bfc8-f13434af9c10',
#  'Pydantic AI': 'b1f7634f-4452-4c24-a70b-9fd66fd1a9f1',
#  'LangChain': '29ebabe3-5ea2-41f9-9e86-88d625d866e4',
#  'LiteLLM': '829e65fe-96f4-4106-a1f9-93b0ca9600ef',
#  'AWS Bedrock': 'ff55ca54-03a7-4a35-8fb4-c7e3e612b495',
#  'scalable, robust LLM-powered automation': 'd3054a7d-f46d-445e-9101-24fd370dd369',
#  'Microservices system': '40d18f4b-3fde-4a36-8c7f-65cb6163aee1',
#  'Kubernetes (Kind)': '22e4dccb-a886-4a24-ab74-2d77ba9a7ef2',
#  'observability stack': '1a91a43b-c781-45a2-b6ff-3bd9b1810449',
#  'Observability stack': '80469b24-ef5a-47f8-a031-9914879cda4c',
#  'Grafana': '2a621c53-b2f2-4f5c-91c9-13715fe3f9dc',
#  'Loki': '0dc546e2-7c0f-4007-a4da-b56418bc57f1',
#  'Tempo': '21cdb92e-5cfd-4149-ad77-037f8a880de8',
#  'Model Context Protocol (MCP) servers': '51edb252-e23f-47ae-a941-c52aa0e8b1d0',
#  'YAML-driven agent configuration': 'e8dba05c-730b-4c66-8677-22ffb6c08c9a',
#  'custom MCP integrations': 'babeb6bd-bf61-443c-8f4b-550ec62e4034',
#  'dynamic, code-free deployment for non-technical users': 'df7fe0ca-611c-4b2c-9a87-bf86bc846642',
#  'Real-time, persistent conversation workflows': '1ef598cf-e499-4937-a011-faf1caebf266',
#  'FastAPI backend': '62e37a44-0757-4d3d-8d04-8be6267dc0f4',
#  'session durability': 'bd49c7b0-4484-4143-8dca-4f4224cb4f22',
#  'state management': 'ee6f2d3b-d404-4fc8-b9b5-a1cc82e5f924',
#  'Configuration and workflow deployments': '734a5e87-470c-46fe-a095-659b7e70a512',
#  'ArgoCD': '98c6bba2-96aa-47ec-98c1-24519d321a0c',
#  'Argo Workflows': 'ac200d8d-731c-49d3-a6f0-7c564e3647c7',
#  'automated, reliable releases': '932a2fd5-b02c-4163-b9c1-b1e32a1efea2',
#  'Production-grade, multi-agent AI platform': '73dab8e9-04a1-4add-b8a6-1a34dafc896a',
#  'person (author/engineer)': 'fc34a736-5b67-4341-a467-0de9c5905118',
#  'Key Technologies': '0198033e-4911-4a8c-b9d2-122efa361dee',
#  'Kubernetes': 'bb85b21f-48de-4c6e-a710-d8bda94c5d43',
#  'FastAPI': '452ceb25-6517-403b-8bd9-3bcb8d2770f2',
#  'TemporalIO': '7a691345-ea46-47a6-953b-4512091d5b56',
#  'MCP integration': '8095cb34-c266-4fab-9c64-87341eba68d2',
#  'Helm': 'fa6c85de-70c6-4412-b298-0e11651d9e9a',
#  'Git': '3b9ffb4d-cdae-42f7-a82b-d088e21d7e1b',
#  'GitHub': '75b0fc08-b34c-4c38-a538-283a5b5bd5df',
#  'YAML': '05e2c82c-aced-4dee-913b-ffd6ef4819a1',
#  'microservices': 'edebc5dd-7c18-457b-8d51-d69a250efc0d',
#  'AI/ML solutions': '73f1d89e-f967-4162-a9e0-ea04aed552be',
#  'GCP ecosystem': '6c4fa70a-4ba8-4c2c-8032-ed34a7e34321',
#  'optimizing customer workflows': '069b6877-9da3-4829-8de4-301d0fe569e1',
#  'customer workflows': '0095ea48-b3f8-47a2-8b4f-b449e2846602',
#  'efficiency': '8727602b-3552-4aeb-9a7d-f5b9077f6209',
#  'scalability': '4d5eff50-c0e5-4505-b936-d15f5a274a76',
#  'Vertex AI': '55482ee9-c22d-4a6b-a667-a69261e2a388',
#  'AutoML': 'aa84394a-6431-45f9-bd37-420773816094',
#  'Vertex AI Pipelines': '011e30aa-26e1-42f6-88b6-433c5b51846c',
#  'BigQuery ML': '8e7b30d4-8f87-409d-818e-66fc31c3efd0',
#  'custom machine learning models': 'ad5231a3-9cac-42a2-9f7b-58533ec4c969',
#  'PyTorch': '28ec9559-daf6-4b37-81b5-5cb78cbccbc1',
#  "GCP's Model Garden": 'b81cbe1a-1687-4e3d-ba5f-c2c43d8c4638',
#  'model selection': '58c05d19-a105-4b6d-a264-97b0f9ade3b0',
#  'specialized tasks': '9743db07-41f5-4f3c-9dae-a4b9444e5246',
#  'regression': 'a3a6dd86-fa20-41b3-aae4-a7decc4c7540',
#  'classification': '008929a6-c83e-4fe2-a87f-4ecd3b91c8d8',
#  'fine-tuning for GenAI': 'ac89f882-1862-46e5-bfec-5fe4c8c5deed',
#  'document processing': 'dcebefe0-6c7d-4613-b45e-ed4c0164483d',
#  'Document AI': 'ad330c8c-5ce5-4674-843b-9ed5ad9ddfcf',
#  'information extraction': '4c289b9f-912e-4e28-8d5f-c5d2bd3b0142',
#  'data preprocessing': '98a8c417-4e94-41f8-bd9b-28172b042da5',
#  'BigQuery': '1a50e541-a572-4d7d-bbbd-fba812a9b0c4',
#  'exploratory analysis': '755144a8-c674-448d-8a04-539e4da38a79',
#  'feature engineering': '7212dd20-51f0-4630-8c60-fb60e4d04cf5',
#  'teams': '1d981534-bdf4-4e35-b1b0-7cb5da3c1b1b',
#  'customer-facing products': 'b2858600-90ac-455f-af06-a2cf0a8a89de',
#  'solutions': '69f14175-7b27-4094-bc52-8309a536fbe4',
#  'MLOps best practices on GCP': 'c8433865-e023-43be-a58b-0070e5c692db',
#  'Model Garden': '67a47759-951b-4830-a8b1-3a1f6eabafa4',
#  'IAM': '497af705-bca1-4b93-a33d-cf31b0493868',
#  'GenAI': 'f505a1b9-93eb-4d61-a458-385bc85697fe',
#  'GCP MLOps': '024a3002-f926-4843-9904-24a02b980920',
#  'regression/classification models': '13e99871-f30f-40f5-81ac-b55ae949880a',
#  'data processing': '77f4a623-aa1c-4a46-ad56-9c2e7daedf1d',
#  'Predictive Modeling': 'aa4bd083-542a-4a0d-b25b-c8338543e018',
#  'A/B Testing': '88a5fda0-1f4c-4613-8029-38a24455363f',
#  'Web Scraping': '3b4c945a-4584-416b-8799-b814759813e4',
#  'NLP': '393156c5-9ac4-4eec-b54a-a1489f9195a2',
#  'MLOps best practices': '63ff7e44-e343-4fd3-837a-7d603c2b5b96',
#  'GCP': '6b0724ce-d410-4df7-960b-a11be544fc1f',
#  'nirpot@gmail.com': 'b09a70ea-d424-4904-a08a-ef8402d16cde',
#  '+972-5222-73418': '1b9ccf24-e876-4943-b343-4d4ede17427c',
#  'English': 'bcae3ceb-cf48-4d3b-b6eb-3ed0f147c509',
#  'Native': 'cf8f8466-5f6a-4d9e-80f5-f0b208853b0e',
#  'Hebrew': 'a716046b-4389-423b-81f1-159851d33e29',
#  'United States': '7e445197-4476-41ed-a63b-95b254f19c70',
#  'Israel': '759eaa4d-bb0c-41e6-b827-364df97c09bd',
#  "Israel's security decisions": '66a83477-eb6d-4fed-a8b5-b4ce97d811d7',
#  'Donald Trump': '5bb406a8-c6f8-4004-bdd1-980fb16808da',
#  'Benjamin Netanyahu': '106634ce-dc45-436b-93da-5f000d3a06be',
#  "Donald Trump's support": '5e510e1d-5f66-4989-b417-fa5f9af224ca',
#  "Netanyahu's reelection prospects": 'e0708856-16f7-4e20-b61c-0fecce7e0da6',
#  'Joe Biden': '101b2fe7-3c44-4ba5-b7f1-66d38ca61fc5',
#  'Netanyahu': '441e3434-bcac-4f2c-96a9-428784bb21e9',
#  'Gaza': '37177ecd-16cc-4a45-a0cb-4bc09c359a43',
#  'West Bank': '5a3c9398-1332-47a7-b775-fd0d3170280f',
#  'Civil-Military Coordination Center in Israel': '9f1ddeed-1b5a-466a-9848-a7634a1a9a64',
#  'humanitarian assistance to Gaza': 'c11adbe6-44ad-4d04-b8c8-5c417536d1b1',
#  'UN Security Council resolution': 'ceea0144-dd2c-43ba-8b99-64d46f91d08d',
#  'UN Security Council': 'c6e01eef-7d0e-45d8-a1f7-7884eb7fbed1',
#  'multinational stabilization force': '6f99df92-3347-4c90-9423-7ca2de056398',
#  'multinational stabilization force duration (2 years)': 'dfbcb42f-7a54-48bc-a152-383da842f573',
#  'UN Security Council in national policy': '8f366194-6df1-4cb7-80e3-608d4e8d3ce8',
#  'Israeli wishes': 'f721e3e1-1f02-4f0d-9125-547e267562d2',
#  'Recep Tayyip Erdoğan': '30b2c250-b5bb-47c8-82b5-3cf7a95c94bc',
#  'Hamas': 'bb810519-adf9-4aff-aba8-dd73c20180bc',
#  'Türkiye from stabilization force': 'e6d2d195-6d9f-42e2-816b-022258bf0f68',
#  "Israel's policy trajectory": '55ab2a04-90cd-470e-aacd-7d8cf6ceae51',
#  'Trump-Netanyahu relationship': '6c6434dd-6ace-4546-8f96-e22d168cfa7e',
#  "Israel's freedom of action in Gaza": 'efa6db3e-7db6-4544-96d3-2c1d54c4393a',
#  "American Jews' support for Israeli policy": '36e079cb-9969-46c2-b9d1-588c9053a22f',
#  'USA': '1df25bbc-a136-41f9-8814-77d87e863164',
#  'Middle East': 'dc7ca436-3d8f-4d8a-8cfd-707e12dcbc84',
#  'Trump': '6dfbe3c3-7814-4f20-9b14-8a8371755395',
#  'Bash': 'cf7add4f-e0a0-4c66-8fbd-1ed8fa2c4c0c',
#  'General Scripting/Automation': '82e7a015-5a71-4274-b666-91034b3f2c56',
#  'General Purpose Programming': 'bb28c092-e28c-4b09-bda9-1c6e8f5f6372',
#  'Non-relational Databases': '2aed87bf-4480-4ca4-8257-f10334b6965d',
#  'Relational Databases': '37eb6b3d-e0f8-474a-bf81-102afd82ceae',
#  'BIG-QUERY': '0ddadc87-877c-4656-a1a6-143b54c98be0',
#  'Google Cloud Platform': '680a1d55-a0fc-43ad-ab1b-55ac7a1575d1',
#  'Go (Golang)': 'b167e1c6-8c4e-449e-acea-5c29e3419224',
#  'Structured Query Language': 'f79fa7cd-4102-4e9a-96dc-4edcfabd9784',
#  'Not Only SQL': '550ef7c2-254d-4ff3-b966-00c2af92b58c',
#  'Google Cloud Functions': 'bcf53b86-34d2-4f03-9b5a-0b97b28e5e8b',
#  'Google Cloud Run': '73d40a9b-9f59-4529-85f5-4e9771a71f7f',
#  'Google Storage Buckets': '237b2d0e-744a-4790-8127-5e0758e83063',
#  'Google': '0ba73ff3-53ea-4dee-8e6b-5043bb44c288',
#  'Amazon': '60b1c10a-6d07-4a5b-8c06-879ec056a951',
#  'Azure': 'ef855cd0-4b40-48fb-9291-8983a0e2cd35',
#  'Microsoft': 'f1719ad9-272a-4c68-b123-d5810b5f918e',
#  'Github': '55076f67-f21c-41bd-a3ae-567193c8da46',
#  'Airflow': '22471786-e7fa-4063-a7d0-94e9ad9572a8',
#  'MongoDB': 'dc537ad0-f19a-4dc3-8025-d951f3357caa',
#  'ElasticSearch': 'd70628f8-bd46-4433-9577-a66f648e061b',
#  'RabbitMQ': '63d97ff9-c845-48b1-8357-ab4f12e96294',
#  'Sklearn': 'e6cb671a-d981-4927-80ea-30d178ee7121',
#  'Python library': '9dda8aac-c510-4474-b5f0-62b68a5a6c17',
#  'XGBoost': 'dabcc808-d88b-4b71-b759-8c3489e09439',
#  'Pytorch': 'd145b11c-1c68-4fd0-80ec-3f74c4588881',
#  'Scipy': 'd70d9b5f-9fab-4f6c-8cc7-2d18bdbf44c3',
#  'Numpy': '940c18f6-18f3-4ebb-8a7a-164ea9b01a53',
#  'Pandas': 'a4475377-3906-4c44-8f37-a837ec6a06ba',
#  'Polars': 'b480e0c0-581d-4f9d-b0ed-963c1a3c074b',
#  'OpenCV': 'c544864a-df66-4bf2-ab4e-4986edcea83d',
#  'Langchain': '385a694c-6bb5-41a5-bee8-00462e2bb51d',
#  'Llamaindex': '4e489d96-0350-4b6d-985c-58c774e31e46',
#  'HuggingFace': '9d7269f6-21ab-4808-9783-b01896a6d13d',
#  'OpenAI': '019fa76f-b630-4e7b-9019-b978b9770844',
#  'Scikit-learn': '8196b4b4-14d6-4516-824c-390bfbd8d82c',
#  'numerical computation': '2bbd889d-9f17-4c11-b36b-935f11d062e0',
#  'data analysis': '327c6df1-0b2f-4f4f-a2fb-a363b6b427f8',
#  'data manipulation': 'a1e8f213-a6b9-45e3-9cd1-672a46ba0db1',
#  'scientific computation': '8790e0c7-8a6c-42de-9ce5-bdaede9fbd36',
#  'deep learning': '640b1f05-ca58-46ee-8a3a-cc85d73e09ea',
#  'natural language processing': '75b6c44d-d1cb-4a7c-bdbb-5b90493574bc',
#  'document indexing': '60ef6428-477f-4951-a0be-cb352ad1c616',
#  'Infinity Labs': '62c7301e-d1da-48a4-87be-82641c274990',
#  'AI Engineer Bootcamp': '29a2d219-aa2a-46d5-8a5d-977a55f13dd9',
#  'Artificial Intelligence': '21d1f917-52a6-4d3a-a723-7e0b00f73e14',
#  'Software Engineering': 'b23ba0be-809a-4b71-9f4f-9949831aff8a',
#  'Data Science': '9223a1e2-583a-4c50-8cbd-43f0cde12145',
#  'AI Engineers': '028f8757-0ad4-493c-8786-70366c6d6f49',
#  'Machine Learning Engineers': '44b84bd3-7f63-46d5-ae5d-4878614a56fe',
#  'Data Scientists': 'e794d42d-7c86-4556-8f7a-b00f9dc8721c',
#  'TensorFlow': '2317699c-a72d-4f5b-874f-4653f33b3688',
#  'Machine Learning Frameworks': '72e52acc-d1d6-4f84-9313-b937fcd615ef',
#  'Programming': '2109a9ef-ea35-4fc6-bda3-33863877c69f',
#  'Advanced Programming': 'bdd1bec5-c639-422d-8c35-60d6b417a5c6',
#  'Web Development': 'ec7e481e-b79b-43a1-8eca-15a6a8173f61',
#  'Shell Scripting': 'da9556fa-89c9-49e7-a307-7588db7e85bd',
#  'Version Control': '6e83555e-5bb6-4c52-9d27-c9dd9f302888',
#  'Data Management': '4576a239-d11b-431b-9d3c-77d56047d596',
#  'High-impact careers in tech': 'ada76395-61ed-46f9-a531-a0f64b199b15',
#  'Bootcamp Participant': '14d78504-93cd-4323-9d3f-a265e97ded6a',
#  'Practical Experience': 'dbbef801-9235-4f17-b51e-6481fd867382',
#  'Technical Foundation': '9f7881a6-0bd8-4dd1-90b4-8b3918065690',
#  'Portfolio': '5a604eeb-d817-40d6-9f1e-82fdc4a67f5c',
#  'Real-time code review': '4c67bcd7-d806-46ac-a1ab-dc2350d40c19',
#  'Feedback from industry experts': '225a9163-8319-4dbc-a152-d3a37c65c291',
#  'Daily Communication': '78f276cd-b938-4cbe-bba9-fb89859601d0',
#  'Solving Global Challenges': 'd1cf74f3-9551-4f77-b82e-cb99f6c984f9',
#  'Bootcamp': '8d01518f-e939-438b-a949-6c838fb98441',
#  'None': '8f1dac72-5380-48ac-bb02-57010d17c6b4',
#  'Flexible Payment Plans': '678311a0-db24-4c82-ae79-e8e2c95c10eb',
#  '6-12 Months': '7b909d25-9184-41ba-adbd-f42941f06a9b',
#  '40 Hours per Week': '8572d13d-21fe-42a2-b9b2-a375b660174c',
#  'Professionals': 'b743c4f5-fdf9-4bde-99f4-4a1faab38ad4',
#  'AI-focused roles': '189b03dd-2937-4151-87ce-1ea1f784a728',
#  'Individuals with engineering/math/science background': 'fcd4fe5c-4ce2-4c59-b3f2-19b32d1a344e',
#  'Individuals with no coding/technical background': '71b61492-6b2b-450f-89db-90b91aa245c1',
#  'AI domain': '781d6b79-f286-45d8-9c4c-4e51456fb41d',
#  'Developers or engineers': '6145b496-9546-491e-9593-1ea8a1d2db41',
#  'Visionaries': 'c35fd968-9d29-42ec-83a0-825885286d3a',
#  'AI-powered products': '248633dc-4e54-4447-ae07-1605138f6991',
#  'Data-driven solutions': 'ab85f6e0-5547-4f17-8762-ffe2be76f16a',
#  'Leaders': '3cd5f7cc-d486-4730-a30d-776cb77e310c',
#  'AI concepts': '1d7117c0-49c2-4363-8f5e-0cb6c87a9795',
#  'Technical Teams': '73e0a1a3-3573-417e-9899-a80a4c4aa6dd',
#  'Stakeholders': '9193fef9-351c-41c4-8e58-cd6edb553fd2',
#  'Individuals passionate about problem-solving': '8d564083-bdec-4512-bcb2-6da355dc385b',
#  'AI-driven economy': '90043c41-ca64-4884-942b-8e992215ce69',
#  'Nir-Vim Integrated Development Environment (IDE)': '96bff384-3203-4c93-8fb6-4db0732bd2c5',
#  'Vim': 'a346c6f1-407e-4f48-b516-0811ca1da89e',
#  'Neovim': '21fbe480-84d3-4e6a-bd59-c0c302a3a95a',
#  'Integrated Development Environment': 'fe126285-858b-4917-a57f-92db6cbe5583',
#  'Wikipedia Scraping Project': '4a84d9bc-11c7-4bcc-831d-46637d01c6ed',
#  'Wikipedia': '97b92769-1199-4ed1-a31d-74c0d145173a',
#  'Recommendation System (RecSys)': '72971d93-7232-4c3f-9d95-c2c60b3ea337',
#  'Factorization Machine': 'a8d93962-19d1-4f0f-8dcf-a69a21d278f4',
#  'Siamese Neural Network': 'ae8c009d-5a4d-461d-bc61-f277776b3ab1',
#  'SQL LLM Agent': 'e701a84d-ec8e-4169-b300-74dff619134c',
#  'Large Language Model': '5ab65a4b-a758-487b-8418-8c2b82006f60',
#  'AI-Powered ECG': 'c0f5b8dc-a150-4370-bb27-df3abe9ec60a',
#  'Classification System': '4ee427d3-266b-46be-9531-1befdf51d4c7',
#  'System': '1047c42e-9cee-4a86-b7c3-8b05c203b7ad',
#  'Go': 'cb5d0596-5c69-46c1-8a2e-aadf8bdc4186',
#  'Future': 'dff8079f-6aa4-45a9-b14d-8f3d1d588bb6',
#  'Backend': '5d86b6e7-8ec5-4783-8d9e-9d852530e933',
#  'IDE Creation': '149cbe3a-265f-4991-b3e3-3a92d692ad1c',
#  'Individuals': 'd08fa511-12dd-42f1-87eb-09fd1dbbb4c9',
#  'Own IDE in 2025': '717b6183-c335-4fde-993c-b1990310e05d',
#  'GenAI Engineer': 'd5c7b92b-ae72-4a96-ab35-28abb3aea885',
#  '6 Tools in 2025': 'fcdbb4dd-cb9a-458c-a638-75f9b8df13db',
#  'IDE': 'cbba52cf-99aa-46bf-8b15-fe0446bb4f30',
#  'Future of Backend': '96688884-fa78-43b5-afd5-e91615813c0e',
#  'Automation': '14d909d2-d57d-4294-980b-a8e916f31dd5',
#  'Future of AI': 'c247c891-2600-441b-8f8b-e759875c7ef6'}

# %% [markdown]
# ---

# %% [markdown]
# ## Ingest to Qdrant

# %%
from rag_handler.qdrant_orchestrator import QdrantOrchestrator

qdrant_key = None
collection_name = "QdrantRagCollection"

# %%
qdrant_orchestrator = QdrantOrchestrator(qdrant_url=qdrant_url, qdrant_key=qdrant_key)

# %%
qdrant_orchestrator.create_collection()
# Out:
# Skipping creating collection; 'QdrantRagCollection' already exists.

# %%
# ingesting embedded data to qdrant:
qdrant_orchestrator.ingest_to_qdrant(
    collection_name=collection_name, embedded_data=embedded_data
)

# %% [markdown]
# ---
# ## Embedding Tester + Query Embedding

# %%
user_query: str = "who is Nir Potasman?"

# %%
embedded_user_query = chunk_embedder.embedding_text(user_query)
# Out:
# 13:52:08 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:52:08,947 - INFO - Wrapper: Completed Call, calling success_handler

# %%
embedded_user_query = chunk_embedder.embedding_text(user_query)
# Out:
# 13:52:09 - LiteLLM:INFO: utils.py:1307 - Wrapper: Completed Call, calling success_handler
# 2025-11-24 13:52:09,259 - INFO - Wrapper: Completed Call, calling success_handler

# %% [markdown]
# ---
# ## Testing Retriever

# %%
from answering_agent import retriever_search

# %%
retriever_result = retriever_search(
    neo4j_driver=neo4j_driver,
    qdrant_client=qdrant_client,
    collection_name=collection_name,
    embedded_query=embedded_user_query,
)

# %%
retriever_result
# Out:
# RetrieverResult(items=[], metadata={'__retriever': 'QdrantNeo4jRetriever'})

# %%
entity_ids = [item.content.split("'id': '")[1].split("'")[0] for item in retriever_result.items]

# %%
entity_ids
# Out:
# []
